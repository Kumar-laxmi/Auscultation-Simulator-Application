# %%
from pydub import AudioSegment
import os

def combine_audio_files_blank(input_folder, output_path):
    # Ensure the output path has the desired extension (e.g., ".wav")
    output_path = os.path.splitext(output_path)[0] + ".wav"

    # List to store AudioSegment objects
    audio_segments = []

    # Loop through each file in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(".wav"):  # Assuming your files are in WAV format, adjust as needed
            file_path = os.path.join(input_folder, filename)
            audio_segments.append(AudioSegment.from_file(file_path))

    # Combine audio segments
    combined_audio = sum(audio_segments)

    # Export the combined audio to the specified output path
    combined_audio.export(output_path, format="wav")

def create_blank_audio(duration_seconds):
    # Create a blank audio segment
    blank_audio = AudioSegment.silent(duration=int(duration_seconds * 1000))  # duration in milliseconds
    return blank_audio

def speed_up_audio1(input_path, output_path, speed_factor):
    audio = AudioSegment.from_file(input_path)
    sped_up_audio = audio.speedup(playback_speed=(1-speed_factor))
    sped_up_audio.export(output_path, format="wav")

def speed_up_audio2(input_path, output_path, speed_factor):
    audio = AudioSegment.from_file(input_path)
    duration = audio.duration_seconds * (1 - speed_factor)
    sped_up_audio = create_blank_audio(duration)
    sped_up_audio.export(output_path, format="wav")

def combine_audio_files_heart(file_paths, output_path):
    # List to store AudioSegment objects
    audio_segments = []

    # Load each audio file into an AudioSegment
    for file_path in file_paths:
        audio_segments.append(AudioSegment.from_file(file_path))

    # Combine audio segments
    combined_audio = sum(audio_segments)

    # Export the combined audio to the specified output path
    combined_audio.export(output_path, format="wav")

# %% [markdown]
# # Heart

# %% [markdown]
# ### Normal Heart Sound

# %%
combine_audio_files_blank("app/static/audio/heart/normal_heart/A/3", "app/static/audio/heart/normal_heart/A/3.wav")
combine_audio_files_blank("app/static/audio/heart/normal_heart/A/5", "app/static/audio/heart/normal_heart/A/5.wav")

speed_up_audio1("app/static/audio/heart/normal_heart/A/3.wav", "app/static/audio/heart/normal_heart/A/3_comp.wav", 0.07)
speed_up_audio2("app/static/audio/heart/normal_heart/A/5.wav", "app/static/audio/heart/normal_heart/A/5_comp.wav", 0.93)

# Example usage
input_files = [
    "app/static/audio/heart/normal_heart/A/1.wav",
    "app/static/audio/heart/normal_heart/A/2.wav",
    "app/static/audio/heart/normal_heart/A/3_comp.wav",
    "app/static/audio/heart/normal_heart/A/4.wav",
    "app/static/audio/heart/normal_heart/A/5_comp.wav"
]

output_path = "app/static/audio/heart/normal_heart/A/combined_audio.wav"

combine_audio_files_heart(input_files, output_path)

# %%
combine_audio_files_blank("app/static/audio/heart/normal_heart/E/3", "app/static/audio/heart/normal_heart/E/3.wav")
combine_audio_files_blank("app/static/audio/heart/normal_heart/E/5", "app/static/audio/heart/normal_heart/E/5.wav")

speed_up_audio1("app/static/audio/heart/normal_heart/E/3.wav", "app/static/audio/heart/normal_heart/E/3_comp.wav", 0.07)
speed_up_audio2("app/static/audio/heart/normal_heart/E/5.wav", "app/static/audio/heart/normal_heart/E/5_comp.wav", 0.93)

# Example usage
input_files = [
    "app/static/audio/heart/normal_heart/E/1.wav",
    "app/static/audio/heart/normal_heart/E/2.wav",
    "app/static/audio/heart/normal_heart/E/3_comp.wav",
    "app/static/audio/heart/normal_heart/E/4.wav",
    "app/static/audio/heart/normal_heart/E/5_comp.wav"
]

output_path = "app/static/audio/heart/normal_heart/E/combined_audio.wav"

combine_audio_files_heart(input_files, output_path)

# %%
combine_audio_files_blank("app/static/audio/heart/normal_heart/M/3", "app/static/audio/heart/normal_heart/M/3.wav")
combine_audio_files_blank("app/static/audio/heart/normal_heart/M/5", "app/static/audio/heart/normal_heart/M/5.wav")

speed_up_audio1("app/static/audio/heart/normal_heart/M/3.wav", "app/static/audio/heart/normal_heart/M/3_comp.wav", 0.07)
speed_up_audio2("app/static/audio/heart/normal_heart/M/5.wav", "app/static/audio/heart/normal_heart/M/5_comp.wav", 0.93)

# Example usage
input_files = [
    "app/static/audio/heart/normal_heart/M/1.wav",
    "app/static/audio/heart/normal_heart/M/2.wav",
    "app/static/audio/heart/normal_heart/M/3_comp.wav",
    "app/static/audio/heart/normal_heart/M/4.wav",
    "app/static/audio/heart/normal_heart/M/5_comp.wav"
]

output_path = "app/static/audio/heart/normal_heart/M/combined_audio.wav"

combine_audio_files_heart(input_files, output_path)

# %%
combine_audio_files_blank("app/static/audio/heart/normal_heart/P/3", "app/static/audio/heart/normal_heart/P/3.wav")
combine_audio_files_blank("app/static/audio/heart/normal_heart/P/5", "app/static/audio/heart/normal_heart/P/5.wav")

speed_up_audio1("app/static/audio/heart/normal_heart/P/3.wav", "app/static/audio/heart/normal_heart/P/3_comp.wav", 0.07)
speed_up_audio2("app/static/audio/heart/normal_heart/P/5.wav", "app/static/audio/heart/normal_heart/P/5_comp.wav", 0.93)

# Example usage
input_files = [
    "app/static/audio/heart/normal_heart/P/1.wav",
    "app/static/audio/heart/normal_heart/P/2.wav",
    "app/static/audio/heart/normal_heart/P/3_comp.wav",
    "app/static/audio/heart/normal_heart/P/4.wav",
    "app/static/audio/heart/normal_heart/P/5_comp.wav"
]

output_path = "app/static/audio/heart/normal_heart/P/combined_audio.wav"

combine_audio_files_heart(input_files, output_path)

# %%
combine_audio_files_blank("app/static/audio/heart/normal_heart/T/3", "app/static/audio/heart/normal_heart/T/3.wav")
combine_audio_files_blank("app/static/audio/heart/normal_heart/T/5", "app/static/audio/heart/normal_heart/T/5.wav")

speed_up_audio1("app/static/audio/heart/normal_heart/T/3.wav", "app/static/audio/heart/normal_heart/T/3_comp.wav", 0.07)
speed_up_audio2("app/static/audio/heart/normal_heart/T/5.wav", "app/static/audio/heart/normal_heart/T/5_comp.wav", 0.93)

# Example usage
input_files = [
    "app/static/audio/heart/normal_heart/T/1.wav",
    "app/static/audio/heart/normal_heart/T/2.wav",
    "app/static/audio/heart/normal_heart/T/3_comp.wav",
    "app/static/audio/heart/normal_heart/T/4.wav",
    "app/static/audio/heart/normal_heart/T/5_comp.wav"
]

output_path = "app/static/audio/heart/normal_heart/T/combined_audio.wav"

combine_audio_files_heart(input_files, output_path)

# %% [markdown]
# ### Acute Myocardial Infection

# %%
combine_audio_files_blank("app/static/audio/heart/acute_myocardial_infarction/A/1", "app/static/audio/heart/acute_myocardial_infarction/A/1.wav")
combine_audio_files_blank("app/static/audio/heart/acute_myocardial_infarction/A/3", "app/static/audio/heart/acute_myocardial_infarction/A/3.wav")
combine_audio_files_blank("app/static/audio/heart/acute_myocardial_infarction/A/5", "app/static/audio/heart/acute_myocardial_infarction/A/5.wav")

speed_up_audio1("app/static/audio/heart/acute_myocardial_infarction/A/3.wav", "app/static/audio/heart/acute_myocardial_infarction/A/3_comp.wav", 0.07)
speed_up_audio2("app/static/audio/heart/acute_myocardial_infarction/A/5.wav", "app/static/audio/heart/acute_myocardial_infarction/A/5_comp.wav", 0.93)

# Example usage
input_files = [
    "app/static/audio/heart/acute_myocardial_infarction/A/1.wav",
    "app/static/audio/heart/acute_myocardial_infarction/A/2.wav",
    "app/static/audio/heart/acute_myocardial_infarction/A/3_comp.wav",
    "app/static/audio/heart/acute_myocardial_infarction/A/4.wav",
    "app/static/audio/heart/acute_myocardial_infarction/A/5_comp.wav"
]

output_path = "app/static/audio/heart/acute_myocardial_infarction/A/combined_audio.wav"

combine_audio_files_heart(input_files, output_path)

# %%
combine_audio_files_blank("app/static/audio/heart/acute_myocardial_infarction/E/1", "app/static/audio/heart/acute_myocardial_infarction/E/1.wav")
combine_audio_files_blank("app/static/audio/heart/acute_myocardial_infarction/E/3", "app/static/audio/heart/acute_myocardial_infarction/E/3.wav")
combine_audio_files_blank("app/static/audio/heart/acute_myocardial_infarction/E/5", "app/static/audio/heart/acute_myocardial_infarction/E/5.wav")

speed_up_audio1("app/static/audio/heart/acute_myocardial_infarction/E/3.wav", "app/static/audio/heart/acute_myocardial_infarction/E/3_comp.wav", 0.07)
speed_up_audio2("app/static/audio/heart/acute_myocardial_infarction/E/5.wav", "app/static/audio/heart/acute_myocardial_infarction/E/5_comp.wav", 0.93)

# Example usage
input_files = [
    "app/static/audio/heart/acute_myocardial_infarction/E/1.wav",
    "app/static/audio/heart/acute_myocardial_infarction/E/2.wav",
    "app/static/audio/heart/acute_myocardial_infarction/E/3_comp.wav",
    "app/static/audio/heart/acute_myocardial_infarction/E/4.wav",
    "app/static/audio/heart/acute_myocardial_infarction/E/5_comp.wav"
]

output_path = "app/static/audio/heart/acute_myocardial_infarction/E/combined_audio.wav"

combine_audio_files_heart(input_files, output_path)

# %%
combine_audio_files_blank("app/static/audio/heart/acute_myocardial_infarction/M/1", "app/static/audio/heart/acute_myocardial_infarction/M/1.wav")
combine_audio_files_blank("app/static/audio/heart/acute_myocardial_infarction/M/3", "app/static/audio/heart/acute_myocardial_infarction/M/3.wav")
combine_audio_files_blank("app/static/audio/heart/acute_myocardial_infarction/M/5", "app/static/audio/heart/acute_myocardial_infarction/M/5.wav")

speed_up_audio1("app/static/audio/heart/acute_myocardial_infarction/M/3.wav", "app/static/audio/heart/acute_myocardial_infarction/M/3_comp.wav", 0.07)
speed_up_audio2("app/static/audio/heart/acute_myocardial_infarction/M/5.wav", "app/static/audio/heart/acute_myocardial_infarction/M/5_comp.wav", 0.93)

# Example usage
input_files = [
    "app/static/audio/heart/acute_myocardial_infarction/M/1.wav",
    "app/static/audio/heart/acute_myocardial_infarction/M/2.wav",
    "app/static/audio/heart/acute_myocardial_infarction/M/3_comp.wav",
    "app/static/audio/heart/acute_myocardial_infarction/M/4.wav",
    "app/static/audio/heart/acute_myocardial_infarction/M/5_comp.wav"
]

output_path = "app/static/audio/heart/acute_myocardial_infarction/M/combined_audio.wav"

combine_audio_files_heart(input_files, output_path)

# %%
combine_audio_files_blank("app/static/audio/heart/acute_myocardial_infarction/P/1", "app/static/audio/heart/acute_myocardial_infarction/P/1.wav")
combine_audio_files_blank("app/static/audio/heart/acute_myocardial_infarction/P/3", "app/static/audio/heart/acute_myocardial_infarction/P/3.wav")
combine_audio_files_blank("app/static/audio/heart/acute_myocardial_infarction/P/5", "app/static/audio/heart/acute_myocardial_infarction/P/5.wav")

speed_up_audio1("app/static/audio/heart/acute_myocardial_infarction/P/3.wav", "app/static/audio/heart/acute_myocardial_infarction/P/3_comp.wav", 0.07)
speed_up_audio2("app/static/audio/heart/acute_myocardial_infarction/P/5.wav", "app/static/audio/heart/acute_myocardial_infarction/P/5_comp.wav", 0.93)

# Example usage
input_files = [
    "app/static/audio/heart/acute_myocardial_infarction/P/1.wav",
    "app/static/audio/heart/acute_myocardial_infarction/P/2.wav",
    "app/static/audio/heart/acute_myocardial_infarction/P/3_comp.wav",
    "app/static/audio/heart/acute_myocardial_infarction/P/4.wav",
    "app/static/audio/heart/acute_myocardial_infarction/P/5_comp.wav"
]

output_path = "app/static/audio/heart/acute_myocardial_infarction/P/combined_audio.wav"

combine_audio_files_heart(input_files, output_path)

# %%
combine_audio_files_blank("app/static/audio/heart/acute_myocardial_infarction/T/1", "app/static/audio/heart/acute_myocardial_infarction/T/1.wav")
combine_audio_files_blank("app/static/audio/heart/acute_myocardial_infarction/T/3", "app/static/audio/heart/acute_myocardial_infarction/T/3.wav")
combine_audio_files_blank("app/static/audio/heart/acute_myocardial_infarction/T/5", "app/static/audio/heart/acute_myocardial_infarction/T/5.wav")

speed_up_audio1("app/static/audio/heart/acute_myocardial_infarction/T/3.wav", "app/static/audio/heart/acute_myocardial_infarction/T/3_comp.wav", 0.07)
speed_up_audio2("app/static/audio/heart/acute_myocardial_infarction/T/5.wav", "app/static/audio/heart/acute_myocardial_infarction/T/5_comp.wav", 0.93)

# Example usage
input_files = [
    "app/static/audio/heart/acute_myocardial_infarction/T/1.wav",
    "app/static/audio/heart/acute_myocardial_infarction/T/2.wav",
    "app/static/audio/heart/acute_myocardial_infarction/T/3_comp.wav",
    "app/static/audio/heart/acute_myocardial_infarction/T/4.wav",
    "app/static/audio/heart/acute_myocardial_infarction/T/5_comp.wav"
]

output_path = "app/static/audio/heart/acute_myocardial_infarction/T/combined_audio.wav"

combine_audio_files_heart(input_files, output_path)

# %% [markdown]
# ### Acute Pericarditis

# %%
combine_audio_files_blank("app/static/audio/heart/acute_pericarditis/A/1", "app/static/audio/heart/acute_pericarditis/A/1.wav")
combine_audio_files_blank("app/static/audio/heart/acute_pericarditis/A/3", "app/static/audio/heart/acute_pericarditis/A/3.wav")
combine_audio_files_blank("app/static/audio/heart/acute_pericarditis/A/5", "app/static/audio/heart/acute_pericarditis/A/5.wav")

speed_up_audio1("app/static/audio/heart/acute_pericarditis/A/3.wav", "app/static/audio/heart/acute_pericarditis/A/3_comp.wav", 0.07)
speed_up_audio2("app/static/audio/heart/acute_pericarditis/A/5.wav", "app/static/audio/heart/acute_pericarditis/A/5_comp.wav", 0.93)

# Example usage
input_files = [
    "app/static/audio/heart/acute_pericarditis/A/1.wav",
    "app/static/audio/heart/acute_pericarditis/A/2.wav",
    "app/static/audio/heart/acute_pericarditis/A/3_comp.wav",
    "app/static/audio/heart/acute_pericarditis/A/4.wav",
    "app/static/audio/heart/acute_pericarditis/A/5_comp.wav"
]

output_path = "app/static/audio/heart/acute_pericarditis/A/combined_audio.wav"

combine_audio_files_heart(input_files, output_path)

# %%
combine_audio_files_blank("app/static/audio/heart/acute_pericarditis/E/1", "app/static/audio/heart/acute_pericarditis/E/1.wav")
combine_audio_files_blank("app/static/audio/heart/acute_pericarditis/E/3", "app/static/audio/heart/acute_pericarditis/E/3.wav")
combine_audio_files_blank("app/static/audio/heart/acute_pericarditis/E/5", "app/static/audio/heart/acute_pericarditis/E/5.wav")

speed_up_audio1("app/static/audio/heart/acute_pericarditis/E/3.wav", "app/static/audio/heart/acute_pericarditis/E/3_comp.wav", 0.07)
speed_up_audio2("app/static/audio/heart/acute_pericarditis/E/5.wav", "app/static/audio/heart/acute_pericarditis/E/5_comp.wav", 0.93)

# Example usage
input_files = [
    "app/static/audio/heart/acute_pericarditis/E/1.wav",
    "app/static/audio/heart/acute_pericarditis/E/2.wav",
    "app/static/audio/heart/acute_pericarditis/E/3_comp.wav",
    "app/static/audio/heart/acute_pericarditis/E/4.wav",
    "app/static/audio/heart/acute_pericarditis/E/5_comp.wav"
]

output_path = "app/static/audio/heart/acute_pericarditis/E/combined_audio.wav"

combine_audio_files_heart(input_files, output_path)

# %%
combine_audio_files_blank("app/static/audio/heart/acute_pericarditis/M/1", "app/static/audio/heart/acute_pericarditis/M/1.wav")
combine_audio_files_blank("app/static/audio/heart/acute_pericarditis/M/3", "app/static/audio/heart/acute_pericarditis/M/3.wav")
combine_audio_files_blank("app/static/audio/heart/acute_pericarditis/M/5", "app/static/audio/heart/acute_pericarditis/M/5.wav")

speed_up_audio1("app/static/audio/heart/acute_pericarditis/M/3.wav", "app/static/audio/heart/acute_pericarditis/M/3_comp.wav", 0.07)
speed_up_audio2("app/static/audio/heart/acute_pericarditis/M/5.wav", "app/static/audio/heart/acute_pericarditis/M/5_comp.wav", 0.93)

# Example usage
input_files = [
    "app/static/audio/heart/acute_pericarditis/M/1.wav",
    "app/static/audio/heart/acute_pericarditis/M/2.wav",
    "app/static/audio/heart/acute_pericarditis/M/3_comp.wav",
    "app/static/audio/heart/acute_pericarditis/M/4.wav",
    "app/static/audio/heart/acute_pericarditis/M/5_comp.wav"
]

output_path = "app/static/audio/heart/acute_pericarditis/M/combined_audio.wav"

combine_audio_files_heart(input_files, output_path)

# %%
combine_audio_files_blank("app/static/audio/heart/acute_pericarditis/P/1", "app/static/audio/heart/acute_pericarditis/P/1.wav")
combine_audio_files_blank("app/static/audio/heart/acute_pericarditis/P/3", "app/static/audio/heart/acute_pericarditis/P/3.wav")
combine_audio_files_blank("app/static/audio/heart/acute_pericarditis/P/5", "app/static/audio/heart/acute_pericarditis/P/5.wav")

speed_up_audio1("app/static/audio/heart/acute_pericarditis/P/3.wav", "app/static/audio/heart/acute_pericarditis/P/3_comp.wav", 0.07)
speed_up_audio2("app/static/audio/heart/acute_pericarditis/P/5.wav", "app/static/audio/heart/acute_pericarditis/P/5_comp.wav", 0.93)

# Example usage
input_files = [
    "app/static/audio/heart/acute_pericarditis/P/1.wav",
    "app/static/audio/heart/acute_pericarditis/P/2.wav",
    "app/static/audio/heart/acute_pericarditis/P/3_comp.wav",
    "app/static/audio/heart/acute_pericarditis/P/4.wav",
    "app/static/audio/heart/acute_pericarditis/P/5_comp.wav"
]

output_path = "app/static/audio/heart/acute_pericarditis/P/combined_audio.wav"

combine_audio_files_heart(input_files, output_path)

# %%
combine_audio_files_blank("app/static/audio/heart/acute_pericarditis/T/1", "app/static/audio/heart/acute_pericarditis/T/1.wav")
combine_audio_files_blank("app/static/audio/heart/acute_pericarditis/T/3", "app/static/audio/heart/acute_pericarditis/T/3.wav")
combine_audio_files_blank("app/static/audio/heart/acute_pericarditis/T/5", "app/static/audio/heart/acute_pericarditis/T/5.wav")

speed_up_audio1("app/static/audio/heart/acute_pericarditis/T/3.wav", "app/static/audio/heart/acute_pericarditis/T/3_comp.wav", 0.07)
speed_up_audio2("app/static/audio/heart/acute_pericarditis/T/5.wav", "app/static/audio/heart/acute_pericarditis/T/5_comp.wav", 0.93)

# Example usage
input_files = [
    "app/static/audio/heart/acute_pericarditis/T/1.wav",
    "app/static/audio/heart/acute_pericarditis/T/2.wav",
    "app/static/audio/heart/acute_pericarditis/T/3_comp.wav",
    "app/static/audio/heart/acute_pericarditis/T/4.wav",
    "app/static/audio/heart/acute_pericarditis/T/5_comp.wav"
]

output_path = "app/static/audio/heart/acute_pericarditis/T/combined_audio.wav"

combine_audio_files_heart(input_files, output_path)

# %% [markdown]
# ### Aortic Stenosis and Regurgitation

# %%
combine_audio_files_blank("app/static/audio/heart/aortic_stenosis_and_regurgitation/A/1", "app/static/audio/heart/aortic_stenosis_and_regurgitation/A/1.wav")
combine_audio_files_blank("app/static/audio/heart/aortic_stenosis_and_regurgitation/A/3", "app/static/audio/heart/aortic_stenosis_and_regurgitation/A/3.wav")
combine_audio_files_blank("app/static/audio/heart/aortic_stenosis_and_regurgitation/A/5", "app/static/audio/heart/aortic_stenosis_and_regurgitation/A/5.wav")

speed_up_audio1("app/static/audio/heart/aortic_stenosis_and_regurgitation/A/3.wav", "app/static/audio/heart/aortic_stenosis_and_regurgitation/A/3_comp.wav", 0.07)
speed_up_audio2("app/static/audio/heart/aortic_stenosis_and_regurgitation/A/5.wav", "app/static/audio/heart/aortic_stenosis_and_regurgitation/A/5_comp.wav", 0.93)

# Example usage
input_files = [
    "app/static/audio/heart/aortic_stenosis_and_regurgitation/A/1.wav",
    "app/static/audio/heart/aortic_stenosis_and_regurgitation/A/2.wav",
    "app/static/audio/heart/aortic_stenosis_and_regurgitation/A/3_comp.wav",
    "app/static/audio/heart/aortic_stenosis_and_regurgitation/A/4.wav",
    "app/static/audio/heart/aortic_stenosis_and_regurgitation/A/5_comp.wav"
]

output_path = "app/static/audio/heart/aortic_stenosis_and_regurgitation/A/combined_audio.wav"

combine_audio_files_heart(input_files, output_path)

# %%
combine_audio_files_blank("app/static/audio/heart/aortic_stenosis_and_regurgitation/E/1", "app/static/audio/heart/aortic_stenosis_and_regurgitation/E/1.wav")
combine_audio_files_blank("app/static/audio/heart/aortic_stenosis_and_regurgitation/E/3", "app/static/audio/heart/aortic_stenosis_and_regurgitation/E/3.wav")
combine_audio_files_blank("app/static/audio/heart/aortic_stenosis_and_regurgitation/E/5", "app/static/audio/heart/aortic_stenosis_and_regurgitation/E/5.wav")

speed_up_audio1("app/static/audio/heart/aortic_stenosis_and_regurgitation/E/3.wav", "app/static/audio/heart/aortic_stenosis_and_regurgitation/E/3_comp.wav", 0.07)
speed_up_audio2("app/static/audio/heart/aortic_stenosis_and_regurgitation/E/5.wav", "app/static/audio/heart/aortic_stenosis_and_regurgitation/E/5_comp.wav", 0.93)

# Example usage
input_files = [
    "app/static/audio/heart/aortic_stenosis_and_regurgitation/E/1.wav",
    "app/static/audio/heart/aortic_stenosis_and_regurgitation/E/2.wav",
    "app/static/audio/heart/aortic_stenosis_and_regurgitation/E/3_comp.wav",
    "app/static/audio/heart/aortic_stenosis_and_regurgitation/E/4.wav",
    "app/static/audio/heart/aortic_stenosis_and_regurgitation/E/5_comp.wav"
]

output_path = "app/static/audio/heart/aortic_stenosis_and_regurgitation/E/combined_audio.wav"

combine_audio_files_heart(input_files, output_path)

# %%
combine_audio_files_blank("app/static/audio/heart/aortic_stenosis_and_regurgitation/M/1", "app/static/audio/heart/aortic_stenosis_and_regurgitation/M/1.wav")
combine_audio_files_blank("app/static/audio/heart/aortic_stenosis_and_regurgitation/M/3", "app/static/audio/heart/aortic_stenosis_and_regurgitation/M/3.wav")
combine_audio_files_blank("app/static/audio/heart/aortic_stenosis_and_regurgitation/M/5", "app/static/audio/heart/aortic_stenosis_and_regurgitation/M/5.wav")

speed_up_audio1("app/static/audio/heart/aortic_stenosis_and_regurgitation/M/3.wav", "app/static/audio/heart/aortic_stenosis_and_regurgitation/M/3_comp.wav", 0.07)
speed_up_audio2("app/static/audio/heart/aortic_stenosis_and_regurgitation/M/5.wav", "app/static/audio/heart/aortic_stenosis_and_regurgitation/M/5_comp.wav", 0.93)

# Example usage
input_files = [
    "app/static/audio/heart/aortic_stenosis_and_regurgitation/M/1.wav",
    "app/static/audio/heart/aortic_stenosis_and_regurgitation/M/2.wav",
    "app/static/audio/heart/aortic_stenosis_and_regurgitation/M/3_comp.wav",
    "app/static/audio/heart/aortic_stenosis_and_regurgitation/M/4.wav",
    "app/static/audio/heart/aortic_stenosis_and_regurgitation/M/5_comp.wav"
]

output_path = "app/static/audio/heart/aortic_stenosis_and_regurgitation/M/combined_audio.wav"

combine_audio_files_heart(input_files, output_path)

# %%
combine_audio_files_blank("app/static/audio/heart/aortic_stenosis_and_regurgitation/P/1", "app/static/audio/heart/aortic_stenosis_and_regurgitation/P/1.wav")
combine_audio_files_blank("app/static/audio/heart/aortic_stenosis_and_regurgitation/P/3", "app/static/audio/heart/aortic_stenosis_and_regurgitation/P/3.wav")
combine_audio_files_blank("app/static/audio/heart/aortic_stenosis_and_regurgitation/P/5", "app/static/audio/heart/aortic_stenosis_and_regurgitation/P/5.wav")

speed_up_audio1("app/static/audio/heart/aortic_stenosis_and_regurgitation/P/3.wav", "app/static/audio/heart/aortic_stenosis_and_regurgitation/P/3_comp.wav", 0.07)
speed_up_audio2("app/static/audio/heart/aortic_stenosis_and_regurgitation/P/5.wav", "app/static/audio/heart/aortic_stenosis_and_regurgitation/P/5_comp.wav", 0.93)

# Example usage
input_files = [
    "app/static/audio/heart/aortic_stenosis_and_regurgitation/P/1.wav",
    "app/static/audio/heart/aortic_stenosis_and_regurgitation/P/2.wav",
    "app/static/audio/heart/aortic_stenosis_and_regurgitation/P/3_comp.wav",
    "app/static/audio/heart/aortic_stenosis_and_regurgitation/P/4.wav",
    "app/static/audio/heart/aortic_stenosis_and_regurgitation/P/5_comp.wav"
]

output_path = "app/static/audio/heart/aortic_stenosis_and_regurgitation/P/combined_audio.wav"

combine_audio_files_heart(input_files, output_path)

# %%
combine_audio_files_blank("app/static/audio/heart/aortic_stenosis_and_regurgitation/T/1", "app/static/audio/heart/aortic_stenosis_and_regurgitation/T/1.wav")
combine_audio_files_blank("app/static/audio/heart/aortic_stenosis_and_regurgitation/T/3", "app/static/audio/heart/aortic_stenosis_and_regurgitation/T/3.wav")
combine_audio_files_blank("app/static/audio/heart/aortic_stenosis_and_regurgitation/T/5", "app/static/audio/heart/aortic_stenosis_and_regurgitation/T/5.wav")

speed_up_audio1("app/static/audio/heart/aortic_stenosis_and_regurgitation/T/3.wav", "app/static/audio/heart/aortic_stenosis_and_regurgitation/T/3_comp.wav", 0.07)
speed_up_audio2("app/static/audio/heart/aortic_stenosis_and_regurgitation/T/5.wav", "app/static/audio/heart/aortic_stenosis_and_regurgitation/T/5_comp.wav", 0.93)

# Example usage
input_files = [
    "app/static/audio/heart/aortic_stenosis_and_regurgitation/T/1.wav",
    "app/static/audio/heart/aortic_stenosis_and_regurgitation/T/2.wav",
    "app/static/audio/heart/aortic_stenosis_and_regurgitation/T/3_comp.wav",
    "app/static/audio/heart/aortic_stenosis_and_regurgitation/T/4.wav",
    "app/static/audio/heart/aortic_stenosis_and_regurgitation/T/5_comp.wav"
]

output_path = "app/static/audio/heart/aortic_stenosis_and_regurgitation/T/combined_audio.wav"

combine_audio_files_heart(input_files, output_path)

# %% [markdown]
# ### Aortic Valve Regurgitation

# %%
### Aortic Stenosis and Regurgitation
combine_audio_files_blank("app/static/audio/heart/aortic_valve_regurgitation/A/1", "app/static/audio/heart/aortic_valve_regurgitation/A/1.wav")
combine_audio_files_blank("app/static/audio/heart/aortic_valve_regurgitation/A/3", "app/static/audio/heart/aortic_valve_regurgitation/A/3.wav")
combine_audio_files_blank("app/static/audio/heart/aortic_valve_regurgitation/A/5", "app/static/audio/heart/aortic_valve_regurgitation/A/5.wav")

speed_up_audio1("app/static/audio/heart/aortic_valve_regurgitation/A/3.wav", "app/static/audio/heart/aortic_valve_regurgitation/A/3_comp.wav", 0.07)
speed_up_audio2("app/static/audio/heart/aortic_valve_regurgitation/A/5.wav", "app/static/audio/heart/aortic_valve_regurgitation/A/5_comp.wav", 0.93)

# Example usage
input_files = [
    "app/static/audio/heart/aortic_valve_regurgitation/A/1.wav",
    "app/static/audio/heart/aortic_valve_regurgitation/A/2.wav",
    "app/static/audio/heart/aortic_valve_regurgitation/A/3_comp.wav",
    "app/static/audio/heart/aortic_valve_regurgitation/A/4.wav",
    "app/static/audio/heart/aortic_valve_regurgitation/A/5_comp.wav"
]

output_path = "app/static/audio/heart/aortic_valve_regurgitation/A/combined_audio.wav"

combine_audio_files_heart(input_files, output_path)
combine_audio_files_blank("app/static/audio/heart/aortic_valve_regurgitation/E/1", "app/static/audio/heart/aortic_valve_regurgitation/E/1.wav")
combine_audio_files_blank("app/static/audio/heart/aortic_valve_regurgitation/E/3", "app/static/audio/heart/aortic_valve_regurgitation/E/3.wav")
combine_audio_files_blank("app/static/audio/heart/aortic_valve_regurgitation/E/5", "app/static/audio/heart/aortic_valve_regurgitation/E/5.wav")

speed_up_audio1("app/static/audio/heart/aortic_valve_regurgitation/E/3.wav", "app/static/audio/heart/aortic_valve_regurgitation/E/3_comp.wav", 0.07)
speed_up_audio2("app/static/audio/heart/aortic_valve_regurgitation/E/5.wav", "app/static/audio/heart/aortic_valve_regurgitation/E/5_comp.wav", 0.93)

# Example usage
input_files = [
    "app/static/audio/heart/aortic_valve_regurgitation/E/1.wav",
    "app/static/audio/heart/aortic_valve_regurgitation/E/2.wav",
    "app/static/audio/heart/aortic_valve_regurgitation/E/3_comp.wav",
    "app/static/audio/heart/aortic_valve_regurgitation/E/4.wav",
    "app/static/audio/heart/aortic_valve_regurgitation/E/5_comp.wav"
]

output_path = "app/static/audio/heart/aortic_valve_regurgitation/E/combined_audio.wav"

combine_audio_files_heart(input_files, output_path)
combine_audio_files_blank("app/static/audio/heart/aortic_valve_regurgitation/M/1", "app/static/audio/heart/aortic_valve_regurgitation/M/1.wav")
combine_audio_files_blank("app/static/audio/heart/aortic_valve_regurgitation/M/3", "app/static/audio/heart/aortic_valve_regurgitation/M/3.wav")
combine_audio_files_blank("app/static/audio/heart/aortic_valve_regurgitation/M/5", "app/static/audio/heart/aortic_valve_regurgitation/M/5.wav")

speed_up_audio1("app/static/audio/heart/aortic_valve_regurgitation/M/3.wav", "app/static/audio/heart/aortic_valve_regurgitation/M/3_comp.wav", 0.07)
speed_up_audio2("app/static/audio/heart/aortic_valve_regurgitation/M/5.wav", "app/static/audio/heart/aortic_valve_regurgitation/M/5_comp.wav", 0.93)

# Example usage
input_files = [
    "app/static/audio/heart/aortic_valve_regurgitation/M/1.wav",
    "app/static/audio/heart/aortic_valve_regurgitation/M/2.wav",
    "app/static/audio/heart/aortic_valve_regurgitation/M/3_comp.wav",
    "app/static/audio/heart/aortic_valve_regurgitation/M/4.wav",
    "app/static/audio/heart/aortic_valve_regurgitation/M/5_comp.wav"
]

output_path = "app/static/audio/heart/aortic_valve_regurgitation/M/combined_audio.wav"

combine_audio_files_heart(input_files, output_path)
combine_audio_files_blank("app/static/audio/heart/aortic_valve_regurgitation/P/1", "app/static/audio/heart/aortic_valve_regurgitation/P/1.wav")
combine_audio_files_blank("app/static/audio/heart/aortic_valve_regurgitation/P/3", "app/static/audio/heart/aortic_valve_regurgitation/P/3.wav")
combine_audio_files_blank("app/static/audio/heart/aortic_valve_regurgitation/P/5", "app/static/audio/heart/aortic_valve_regurgitation/P/5.wav")

speed_up_audio1("app/static/audio/heart/aortic_valve_regurgitation/P/3.wav", "app/static/audio/heart/aortic_valve_regurgitation/P/3_comp.wav", 0.07)
speed_up_audio2("app/static/audio/heart/aortic_valve_regurgitation/P/5.wav", "app/static/audio/heart/aortic_valve_regurgitation/P/5_comp.wav", 0.93)

# Example usage
input_files = [
    "app/static/audio/heart/aortic_valve_regurgitation/P/1.wav",
    "app/static/audio/heart/aortic_valve_regurgitation/P/2.wav",
    "app/static/audio/heart/aortic_valve_regurgitation/P/3_comp.wav",
    "app/static/audio/heart/aortic_valve_regurgitation/P/4.wav",
    "app/static/audio/heart/aortic_valve_regurgitation/P/5_comp.wav"
]

output_path = "app/static/audio/heart/aortic_valve_regurgitation/P/combined_audio.wav"

combine_audio_files_heart(input_files, output_path)
combine_audio_files_blank("app/static/audio/heart/aortic_valve_regurgitation/T/1", "app/static/audio/heart/aortic_valve_regurgitation/T/1.wav")
combine_audio_files_blank("app/static/audio/heart/aortic_valve_regurgitation/T/3", "app/static/audio/heart/aortic_valve_regurgitation/T/3.wav")
combine_audio_files_blank("app/static/audio/heart/aortic_valve_regurgitation/T/5", "app/static/audio/heart/aortic_valve_regurgitation/T/5.wav")

speed_up_audio1("app/static/audio/heart/aortic_valve_regurgitation/T/3.wav", "app/static/audio/heart/aortic_valve_regurgitation/T/3_comp.wav", 0.07)
speed_up_audio2("app/static/audio/heart/aortic_valve_regurgitation/T/5.wav", "app/static/audio/heart/aortic_valve_regurgitation/T/5_comp.wav", 0.93)

# Example usage
input_files = [
    "app/static/audio/heart/aortic_valve_regurgitation/T/1.wav",
    "app/static/audio/heart/aortic_valve_regurgitation/T/2.wav",
    "app/static/audio/heart/aortic_valve_regurgitation/T/3_comp.wav",
    "app/static/audio/heart/aortic_valve_regurgitation/T/4.wav",
    "app/static/audio/heart/aortic_valve_regurgitation/T/5_comp.wav"
]

output_path = "app/static/audio/heart/aortic_valve_regurgitation/T/combined_audio.wav"

combine_audio_files_heart(input_files, output_path)

# %% [markdown]
# ### AUTOMATION CELL - 1

# %%
all_folders = ['atrial_septal_defect',
 'austin_flint_murmur',
 'coarctation_of_the_aorta',
 'congenital_aortic_stenosis',
 'congestive_heart_failure',
 'continuous_murmur',
 'diastolic_murmur',
 'dilated_cardiomyopathy',
 'early_systolic_murmur',
 'ebsteins_anomaly',
 'fourth_heart_sound_gallop',
 'functional_murmur',
 'holosystolic_murmur',
 'hypertrophic_cardiomyopathy',
 'mid-systolic_murmur',
 'mitral_stenosis_and_regurgitation',
 'mitral_stenosis_and_tricuspid_regurgitation',
 'mitral_valve_prolapse',
 'mitral_valve_regurgitation',
 'mitral_valve_stenosis',
 'opening_snap',
 'patent_ductus_arteriosus',
 'pericardial_rub',
 'pulmonary_hypertension',
 'pulmonary_valve_regurgitation',
 'pulmonary_valve_stenosis',
 'split_first_heart_sound',
 'split_second_heart_sound',
 'stills_murmur',
 'systemic_hypertension',
 'tetralogy_of_fallot',
 'third_heart_sound_gallop',
 'tricuspid_valve_regurgitation',
 'ventricular_aneurysm',
 'ventricular_septal_defect']

# %%
for sound_name in all_folders:
    ### Aortic Stenosis and Regurgitation
    combine_audio_files_blank("app/static/audio/heart/{}/A/1".format(sound_name), "app/static/audio/heart/{}/A/1.wav".format(sound_name))
    combine_audio_files_blank("app/static/audio/heart/{}/A/3".format(sound_name), "app/static/audio/heart/{}/A/3.wav".format(sound_name))
    combine_audio_files_blank("app/static/audio/heart/{}/A/5".format(sound_name), "app/static/audio/heart/{}/A/5.wav".format(sound_name))

    speed_up_audio1("app/static/audio/heart/{}/A/3.wav".format(sound_name), "app/static/audio/heart/{}/A/3_comp.wav".format(sound_name), 0.07)
    speed_up_audio2("app/static/audio/heart/{}/A/5.wav".format(sound_name), "app/static/audio/heart/{}/A/5_comp.wav".format(sound_name), 0.93)

    # Example usage
    input_files = [
    "app/static/audio/heart/{}/A/1.wav".format(sound_name),
    "app/static/audio/heart/{}/A/2.wav".format(sound_name),
    "app/static/audio/heart/{}/A/3_comp.wav".format(sound_name),
    "app/static/audio/heart/{}/A/4.wav".format(sound_name),
    "app/static/audio/heart/{}/A/5_comp.wav".format(sound_name)
    ]

    output_path = "app/static/audio/heart/{}/A/combined_audio.wav".format(sound_name)

    combine_audio_files_heart(input_files, output_path)
    combine_audio_files_blank("app/static/audio/heart/{}/E/1".format(sound_name), "app/static/audio/heart/{}/E/1.wav".format(sound_name))
    combine_audio_files_blank("app/static/audio/heart/{}/E/3".format(sound_name), "app/static/audio/heart/{}/E/3.wav".format(sound_name))
    combine_audio_files_blank("app/static/audio/heart/{}/E/5".format(sound_name), "app/static/audio/heart/{}/E/5.wav".format(sound_name))

    speed_up_audio1("app/static/audio/heart/{}/E/3.wav".format(sound_name), "app/static/audio/heart/{}/E/3_comp.wav".format(sound_name), 0.07)
    speed_up_audio2("app/static/audio/heart/{}/E/5.wav".format(sound_name), "app/static/audio/heart/{}/E/5_comp.wav".format(sound_name), 0.93)

    # Example usage
    input_files = [
    "app/static/audio/heart/{}/E/1.wav".format(sound_name),
    "app/static/audio/heart/{}/E/2.wav".format(sound_name),
    "app/static/audio/heart/{}/E/3_comp.wav".format(sound_name),
    "app/static/audio/heart/{}/E/4.wav".format(sound_name),
    "app/static/audio/heart/{}/E/5_comp.wav".format(sound_name)
    ]

    output_path = "app/static/audio/heart/{}/E/combined_audio.wav".format(sound_name)

    combine_audio_files_heart(input_files, output_path)
    combine_audio_files_blank("app/static/audio/heart/{}/M/1".format(sound_name), "app/static/audio/heart/{}/M/1.wav".format(sound_name))
    combine_audio_files_blank("app/static/audio/heart/{}/M/3".format(sound_name), "app/static/audio/heart/{}/M/3.wav".format(sound_name))
    combine_audio_files_blank("app/static/audio/heart/{}/M/5".format(sound_name), "app/static/audio/heart/{}/M/5.wav".format(sound_name))

    speed_up_audio1("app/static/audio/heart/{}/M/3.wav".format(sound_name), "app/static/audio/heart/{}/M/3_comp.wav".format(sound_name), 0.07)
    speed_up_audio2("app/static/audio/heart/{}/M/5.wav".format(sound_name), "app/static/audio/heart/{}/M/5_comp.wav".format(sound_name), 0.93)

    # Example usage
    input_files = [
    "app/static/audio/heart/{}/M/1.wav".format(sound_name),
    "app/static/audio/heart/{}/M/2.wav".format(sound_name),
    "app/static/audio/heart/{}/M/3_comp.wav".format(sound_name),
    "app/static/audio/heart/{}/M/4.wav".format(sound_name),
    "app/static/audio/heart/{}/M/5_comp.wav".format(sound_name)
    ]

    output_path = "app/static/audio/heart/{}/M/combined_audio.wav".format(sound_name)

    combine_audio_files_heart(input_files, output_path)
    combine_audio_files_blank("app/static/audio/heart/{}/P/1".format(sound_name), "app/static/audio/heart/{}/P/1.wav".format(sound_name))
    combine_audio_files_blank("app/static/audio/heart/{}/P/3".format(sound_name), "app/static/audio/heart/{}/P/3.wav".format(sound_name))
    combine_audio_files_blank("app/static/audio/heart/{}/P/5".format(sound_name), "app/static/audio/heart/{}/P/5.wav".format(sound_name))

    speed_up_audio1("app/static/audio/heart/{}/P/3.wav".format(sound_name), "app/static/audio/heart/{}/P/3_comp.wav".format(sound_name), 0.07)
    speed_up_audio2("app/static/audio/heart/{}/P/5.wav".format(sound_name), "app/static/audio/heart/{}/P/5_comp.wav".format(sound_name), 0.93)

    # Example usage
    input_files = [
    "app/static/audio/heart/{}/P/1.wav".format(sound_name),
    "app/static/audio/heart/{}/P/2.wav".format(sound_name),
    "app/static/audio/heart/{}/P/3_comp.wav".format(sound_name),
    "app/static/audio/heart/{}/P/4.wav".format(sound_name),
    "app/static/audio/heart/{}/P/5_comp.wav".format(sound_name)
    ]

    output_path = "app/static/audio/heart/{}/P/combined_audio.wav".format(sound_name)

    combine_audio_files_heart(input_files, output_path)
    combine_audio_files_blank("app/static/audio/heart/{}/T/1".format(sound_name), "app/static/audio/heart/{}/T/1.wav".format(sound_name))
    combine_audio_files_blank("app/static/audio/heart/{}/T/3".format(sound_name), "app/static/audio/heart/{}/T/3.wav".format(sound_name))
    combine_audio_files_blank("app/static/audio/heart/{}/T/5".format(sound_name), "app/static/audio/heart/{}/T/5.wav".format(sound_name))

    speed_up_audio1("app/static/audio/heart/{}/T/3.wav".format(sound_name), "app/static/audio/heart/{}/T/3_comp.wav".format(sound_name), 0.07)
    speed_up_audio2("app/static/audio/heart/{}/T/5.wav".format(sound_name), "app/static/audio/heart/{}/T/5_comp.wav".format(sound_name), 0.93)

    # Example usage
    input_files = [
    "app/static/audio/heart/{}/T/1.wav".format(sound_name),
    "app/static/audio/heart/{}/T/2.wav".format(sound_name),
    "app/static/audio/heart/{}/T/3_comp.wav".format(sound_name),
    "app/static/audio/heart/{}/T/4.wav".format(sound_name),
    "app/static/audio/heart/{}/T/5_comp.wav".format(sound_name)
    ]

    output_path = "app/static/audio/heart/{}/T/combined_audio.wav".format(sound_name)

    combine_audio_files_heart(input_files, output_path)

# %% [markdown]
# ### Deletion test-1

# %%
import os
import shutil

def delete_files_and_folders_except(folder_path, except_file):
    for root, dirs, files in os.walk(folder_path, topdown=False):
        for file in files:
            file_path = os.path.join(root, file)
            if file != except_file:
                os.remove(file_path)
                print(f"Deleted file: {file_path}")

        for dir in dirs:
            dir_path = os.path.join(root, dir)
            shutil.rmtree(dir_path)
            print(f"Deleted folder: {dir_path}")

folder_path_to_clean = 'app/static/audio/heart/aortic_valve_stenosis/A'
except_file_name = 'combined_audio.wav'

delete_files_and_folders_except(folder_path_to_clean, except_file_name)
# Out:
# Deleted folder: app/static/audio/heart/aortic_valve_stenosis/A/1
# Deleted folder: app/static/audio/heart/aortic_valve_stenosis/A/3
# Deleted folder: app/static/audio/heart/aortic_valve_stenosis/A/5

# %%
delete_files_and_folders_except('app/static/audio/heart/aortic_valve_stenosis/E', 'combined_audio.wav')
delete_files_and_folders_except('app/static/audio/heart/aortic_valve_stenosis/M', 'combined_audio.wav')
delete_files_and_folders_except('app/static/audio/heart/aortic_valve_stenosis/P', 'combined_audio.wav')
delete_files_and_folders_except('app/static/audio/heart/aortic_valve_stenosis/T', 'combined_audio.wav')
# Out:
# Deleted file: app/static/audio/heart/aortic_valve_stenosis/E/1/201.wav
# Deleted file: app/static/audio/heart/aortic_valve_stenosis/E/1/1.wav
# Deleted file: app/static/audio/heart/aortic_valve_stenosis/E/1/321.wav
# Deleted file: app/static/audio/heart/aortic_valve_stenosis/E/1/280.wav
# Deleted file: app/static/audio/heart/aortic_valve_stenosis/E/1/250.wav
# Deleted file: app/static/audio/heart/aortic_valve_stenosis/E/3/300.wav
# Deleted file: app/static/audio/heart/aortic_valve_stenosis/E/3/260.wav
# Deleted file: app/static/audio/heart/aortic_valve_stenosis/E/3/100.wav
# Deleted file: app/static/audio/heart/aortic_valve_stenosis/E/3/110.wav
# Deleted file: app/static/audio/heart/aortic_valve_stenosis/E/3/270.wav
# Deleted file: app/static/audio/heart/aortic_valve_stenosis/E/3/310.wav
# Deleted file: app/static/audio/heart/aortic_valve_stenosis/E/3/160.wav
# Deleted file: app/static/audio/heart/aortic_valve_stenosis/E/3/201.wav
# ...

# %%
all_folders = ['atrial_septal_defect',
 'austin_flint_murmur',
 'coarctation_of_the_aorta',
 'congenital_aortic_stenosis',
 'congestive_heart_failure',
 'continuous_murmur',
 'diastolic_murmur',
 'dilated_cardiomyopathy',
 'early_systolic_murmur',
 'ebsteins_anomaly',
 'fourth_heart_sound_gallop',
 'functional_murmur',
 'holosystolic_murmur',
 'hypertrophic_cardiomyopathy',
 'mid-systolic_murmur',
 'mitral_stenosis_and_regurgitation',
 'mitral_stenosis_and_tricuspid_regurgitation',
 'mitral_valve_prolapse',
 'mitral_valve_regurgitation',
 'mitral_valve_stenosis',
 'opening_snap',
 'patent_ductus_arteriosus',
 'pericardial_rub',
 'pulmonary_hypertension',
 'pulmonary_valve_regurgitation',
 'pulmonary_valve_stenosis',
 'split_first_heart_sound',
 'split_second_heart_sound',
 'stills_murmur',
 'systemic_hypertension',
 'tetralogy_of_fallot',
 'third_heart_sound_gallop',
 'tricuspid_valve_regurgitation',
 'ventricular_aneurysm',
 'ventricular_septal_defect']

# %%
for sound in all_folders:
    delete_files_and_folders_except('app/static/audio/heart/{}/A'.format(sound), 'combined_audio.wav')
    delete_files_and_folders_except('app/static/audio/heart/{}/E'.format(sound), 'combined_audio.wav')
    delete_files_and_folders_except('app/static/audio/heart/{}/M'.format(sound), 'combined_audio.wav')
    delete_files_and_folders_except('app/static/audio/heart/{}/P'.format(sound), 'combined_audio.wav')
    delete_files_and_folders_except('app/static/audio/heart/{}/T'.format(sound), 'combined_audio.wav')
# Out:
# Deleted file: app/static/audio/heart/atrial_septal_defect/A/1/201.wav
# Deleted file: app/static/audio/heart/atrial_septal_defect/A/1/1.wav
# Deleted file: app/static/audio/heart/atrial_septal_defect/A/1/321.wav
# Deleted file: app/static/audio/heart/atrial_septal_defect/A/1/280.wav
# Deleted file: app/static/audio/heart/atrial_septal_defect/A/1/250.wav
# Deleted file: app/static/audio/heart/atrial_septal_defect/A/3/300.wav
# Deleted file: app/static/audio/heart/atrial_septal_defect/A/3/260.wav
# Deleted file: app/static/audio/heart/atrial_septal_defect/A/3/100.wav
# Deleted file: app/static/audio/heart/atrial_septal_defect/A/3/110.wav
# Deleted file: app/static/audio/heart/atrial_septal_defect/A/3/270.wav
# Deleted file: app/static/audio/heart/atrial_septal_defect/A/3/310.wav
# Deleted file: app/static/audio/heart/atrial_septal_defect/A/3/160.wav
# Deleted file: app/static/audio/heart/atrial_septal_defect/A/3/201.wav
# ...
